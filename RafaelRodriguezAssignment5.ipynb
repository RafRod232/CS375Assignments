# %% [markdown]
# **Note to grader:** Each question is assigned with a score. The final score will be (sum of actual scores)/(sum of maximum scores)*100. The grading rubrics are shown in the TA guidelines.

# %%
# Grader's area
import numpy as np

maxScore = 0

# %% [markdown]
# # **Assignment 5**
# <br>
#
# <font>

# %%
from IPython.display import Math
from IPython.display import Latex

import numpy as np
import os
import struct

from sklearn.metrics import classification_report,confusion_matrix
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ----------------
# ----------------
# ----------------

# %% [markdown]
# ## <font color='blue'> Question 0. MLP with scikit-learn: Explore outputs for the MNIST dataset [40 pts]</font>
#
# The purpose of this question is to get some practice time with MLP classifiers. We will be using the the MNIST data set.

# %%
# Let's first load the MNIST data set.

from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split


X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
y = y.astype(int)
X = ((X / 255.) - .5) * 2
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=10000, random_state=123, stratify=y)
# Out:
# /home/rafrod513/anaconda3/lib/python3.11/site-packages/sklearn/datasets/_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %% [markdown]
# <br> **Q0-0**: This is the classifier we built in class. Find a setting for *batch_size* and *max_iter*, so that the subsequent fit function **converges**. Converge here is defined as: the training loss does not improve by more than tol=1e-4 for n_iter_no_change=10 consecutive passes over the training set. [10 pts]

# %%
mlp_mnist = MLPClassifier(verbose = True, hidden_layer_sizes=(50,), batch_size = 5, \
                          max_iter=50, solver='sgd', activation='logistic',\
                          learning_rate = 'constant', learning_rate_init = 0.001, random_state=1)

#create the model of mlp(multi layer perceptron) classifier

# %%
mlp_mnist.fit(X_train,y_train)
# fitting the model with the training data
# Out:
# Iteration 1, loss = 0.57329662
# Iteration 2, loss = 0.28629488
# Iteration 3, loss = 0.23811091
# Iteration 4, loss = 0.20762641
# Iteration 5, loss = 0.18553770
# Iteration 6, loss = 0.16929318
# Iteration 7, loss = 0.15646485
# Iteration 8, loss = 0.14587802
# Iteration 9, loss = 0.13694593
# Iteration 10, loss = 0.12970190
# Iteration 11, loss = 0.12320933
# Iteration 12, loss = 0.11772963
# Iteration 13, loss = 0.11267477
# Iteration 14, loss = 0.10835127
# Iteration 15, loss = 0.10453760
# Iteration 16, loss = 0.10073217
# Iteration 17, loss = 0.09726995
# Iteration 18, loss = 0.09425700
# Iteration 19, loss = 0.09151431
# Iteration 20, loss = 0.08889736
# Iteration 21, loss = 0.08643857
# Iteration 22, loss = 0.08418907
# Iteration 23, loss = 0.08249839
# Iteration 24, loss = 0.08000014
# Iteration 25, loss = 0.07834150
# Iteration 26, loss = 0.07665299
# Iteration 27, loss = 0.07502774
# Iteration 28, loss = 0.07348437
# Iteration 29, loss = 0.07206173
# Iteration 30, loss = 0.07059095
# Iteration 31, loss = 0.06904452
# Iteration 32, loss = 0.06804828
# Iteration 33, loss = 0.06670843
# Iteration 34, loss = 0.06531548
# Iteration 35, loss = 0.06463879
# Iteration 36, loss = 0.06318098
# Iteration 37, loss = 0.06233041
# Iteration 38, loss = 0.06147756
# Iteration 39, loss = 0.06044707
# Iteration 40, loss = 0.05937900
# Iteration 41, loss = 0.05860980
# Iteration 42, loss = 0.05802491
# Iteration 43, loss = 0.05700755
# Iteration 44, loss = 0.05620678
# Iteration 45, loss = 0.05553365
# Iteration 46, loss = 0.05483653
# Iteration 47, loss = 0.05419409
# Iteration 48, loss = 0.05357554
# Iteration 49, loss = 0.05269414
# Iteration 50, loss = 0.05199743
# /home/rafrod513/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(activation='logistic', batch_size=5, hidden_layer_sizes=(50,),
#               max_iter=50, random_state=1, solver='sgd', verbose=True)

# %%
predictions = mlp_mnist.predict(X_test)
probability_predictions = mlp_mnist.predict_proba(X_test)

# %% [markdown]
# **Q0-1**: Write a short function that outputs the **second best** prediction for each point, i.e. the label which gets the second highest probability in the softmax output. [10 pts]

# %%
### Your code here
for i in range(len(probability_predictions)):
    arrary = probability_predictions[i].copy()
    arrary.sort()
    secprob = arrary[-2]
    print(f"The point {i} had its second highest probability be {secprob}")
# Out:
# The point 0 had its second highest probability be 0.154339750239973
# The point 1 had its second highest probability be 0.00842990553439723
# The point 2 had its second highest probability be 0.002025475076530754
# The point 3 had its second highest probability be 2.1023041882818667e-05
# The point 4 had its second highest probability be 2.355975738962785e-05
# The point 5 had its second highest probability be 0.0027357385236256746
# The point 6 had its second highest probability be 0.002902136320142312
# The point 7 had its second highest probability be 0.0015889794802402034
# The point 8 had its second highest probability be 0.004254039185100505
# The point 9 had its second highest probability be 0.0007811945951716532
# The point 10 had its second highest probability be 0.0012316882819700624
# The point 11 had its second highest probability be 0.0016208432422327318
# The point 12 had its second highest probability be 5.603727735027386e-06
# The point 13 had its second highest probability be 0.00010287408624929948
# The point 14 had its second highest probability be 0.001075362840132021
# The point 15 had its second highest probability be 0.001409842280804494
# The point 16 had its second highest probability be 3.347061032079077e-06
# The point 17 had its second highest probability be 0.0010064159270200368
# The point 18 had its second highest probability be 2.5136746676882987e-05
# The point 19 had its second highest probability be 4.80506828312151e-05
# The point 20 had its second highest probability be 9.029238332486928e-05
# The point 21 had its second highest probability be 9.161126666643575e-05
# The point 22 had its second highest probability be 2.8485853020881884e-06
# The point 23 had its second highest probability be 0.0009928341037255737
# The point 24 had its second highest probability be 0.0011055899823524857
# The point 25 had its second highest probability be 0.0005836718244683623
# The point 26 had its second highest probability be 0.23398460848573643
# The point 27 had its second highest probability be 0.0036846624320316305
# The point 28 had its second highest probability be 0.01888395522202838
# The point 29 had its second highest probability be 0.020128446556242602
# The point 30 had its second highest probability be 0.0001431791774273622
# The point 31 had its second highest probability be 0.006862933737211245
# The point 32 had its second highest probability be 0.0027676410768245506
# The point 33 had its second highest probability be 0.003248443359616612
# The point 34 had its second highest probability be 0.11095848614668041
# The point 35 had its second highest probability be 0.0006854640009070374
# The point 36 had its second highest probability be 0.24291895839559044
# The point 37 had its second highest probability be 0.0010760881964520554
# The point 38 had its second highest probability be 0.0005346195548121963
# The point 39 had its second highest probability be 0.0034117485833105327
# The point 40 had its second highest probability be 0.019709177342521252
# The point 41 had its second highest probability be 0.004621462136851965
# The point 42 had its second highest probability be 0.0007355051711753158
# The point 43 had its second highest probability be 6.578766892158731e-05
# The point 44 had its second highest probability be 0.11291383831529107
# The point 45 had its second highest probability be 0.003689961769469825
# The point 46 had its second highest probability be 0.0018217664582063163
# The point 47 had its second highest probability be 0.00010524893104954685
# The point 48 had its second highest probability be 0.0003831112206870695
# The point 49 had its second highest probability be 0.001614192377353216
# The point 50 had its second highest probability be 0.002422820489643131
# The point 51 had its second highest probability be 0.0011982438047739928
# The point 52 had its second highest probability be 0.00012670652501863615
# The point 53 had its second highest probability be 0.003144793196471607
# The point 54 had its second highest probability be 9.36138372588919e-06
# The point 55 had its second highest probability be 9.944444562783474e-05
# The point 56 had its second highest probability be 0.0004302293491740602
# The point 57 had its second highest probability be 0.00022848979890956317
# The point 58 had its second highest probability be 0.03015955978788279
# The point 59 had its second highest probability be 0.34789397109881837
# The point 60 had its second highest probability be 0.0003272872513708732
# The point 61 had its second highest probability be 0.0021816491910789364
# The point 62 had its second highest probability be 4.0135259566171375e-06
# The point 63 had its second highest probability be 0.03277257417960981
# The point 64 had its second highest probability be 0.00575035556599462
# The point 65 had its second highest probability be 0.0018861556706259556
# The point 66 had its second highest probability be 0.0009797208408434538
# The point 67 had its second highest probability be 2.884499641917688e-05
# The point 68 had its second highest probability be 0.00013050879741088406
# The point 69 had its second highest probability be 0.0005538503198378309
# The point 70 had its second highest probability be 0.0006246921419712641
# The point 71 had its second highest probability be 0.00035698754719898606
# The point 72 had its second highest probability be 0.0038888805565891076
# The point 73 had its second highest probability be 0.006033979326047295
# The point 74 had its second highest probability be 0.00023114972161980963
# The point 75 had its second highest probability be 0.024415286083075728
# The point 76 had its second highest probability be 4.419412208737068e-05
# The point 77 had its second highest probability be 0.00043046706502156465
# The point 78 had its second highest probability be 7.935651680910425e-05
# The point 79 had its second highest probability be 0.012936350512989803
# The point 80 had its second highest probability be 3.072819372417931e-05
# The point 81 had its second highest probability be 0.04819779880518835
# The point 82 had its second highest probability be 0.2513327711485342
# The point 83 had its second highest probability be 7.916110484636595e-05
# The point 84 had its second highest probability be 0.00045095262588161337
# The point 85 had its second highest probability be 0.00018570206016036794
# The point 86 had its second highest probability be 0.00011043162418376748
# The point 87 had its second highest probability be 0.05928889878854864
# The point 88 had its second highest probability be 4.197464879475586e-05
# The point 89 had its second highest probability be 0.007784415357134023
# The point 90 had its second highest probability be 5.415555708434181e-06
# The point 91 had its second highest probability be 0.00016454824882161732
# The point 92 had its second highest probability be 0.001292359693664881
# The point 93 had its second highest probability be 0.1445235029763743
# The point 94 had its second highest probability be 0.00013114877429475612
# The point 95 had its second highest probability be 1.0388458384801748e-05
# The point 96 had its second highest probability be 0.25237810851457815
# The point 97 had its second highest probability be 1.6051377541956597e-05
# The point 98 had its second highest probability be 0.015506033100324286
# The point 99 had its second highest probability be 4.653532775487859e-05
# The point 100 had its second highest probability be 0.0034742485816348445
# The point 101 had its second highest probability be 0.0007121496596117785
# The point 102 had its second highest probability be 0.21113085939168585
# The point 103 had its second highest probability be 5.432339603612258e-05
# The point 104 had its second highest probability be 9.482000602831655e-05
# The point 105 had its second highest probability be 0.005865680672129479
# The point 106 had its second highest probability be 0.00010510187880966948
# The point 107 had its second highest probability be 0.0011994385527367305
# The point 108 had its second highest probability be 0.00022516880424478046
# The point 109 had its second highest probability be 9.48579088351171e-06
# The point 110 had its second highest probability be 0.08284708992486252
# The point 111 had its second highest probability be 0.00021423585790194047
# The point 112 had its second highest probability be 0.002682525539981164
# The point 113 had its second highest probability be 2.5579808673604453e-05
# The point 114 had its second highest probability be 0.009778789259985982
# The point 115 had its second highest probability be 0.00037858289270813986
# The point 116 had its second highest probability be 0.034513165099665066
# The point 117 had its second highest probability be 0.00019825474740851147
# The point 118 had its second highest probability be 0.000781818757920902
# The point 119 had its second highest probability be 0.3723864294632295
# The point 120 had its second highest probability be 0.00011098163086619777
# The point 121 had its second highest probability be 0.0024733028917842594
# The point 122 had its second highest probability be 0.036656712389128765
# The point 123 had its second highest probability be 0.0012047343665811084
# The point 124 had its second highest probability be 0.07891167363354012
# The point 125 had its second highest probability be 0.0006261437766876516
# The point 126 had its second highest probability be 0.40022520141224915
# The point 127 had its second highest probability be 3.707558144984586e-05
# The point 128 had its second highest probability be 0.00014925192059346288
# The point 129 had its second highest probability be 2.4742724081607372e-06
# The point 130 had its second highest probability be 0.03822573724361775
# The point 131 had its second highest probability be 0.00014509415219306999
# The point 132 had its second highest probability be 0.00036814709421305975
# The point 133 had its second highest probability be 1.843677315371167e-05
# The point 134 had its second highest probability be 0.0004054586827744784
# The point 135 had its second highest probability be 0.0435758170156025
# The point 136 had its second highest probability be 0.21230085852030478
# The point 137 had its second highest probability be 0.0010787750484471872
# The point 138 had its second highest probability be 0.0010594738420202521
# The point 139 had its second highest probability be 1.2405483250882923e-05
# The point 140 had its second highest probability be 0.00012131884202317278
# The point 141 had its second highest probability be 0.0003302957063937573
# The point 142 had its second highest probability be 4.982822664833583e-05
# The point 143 had its second highest probability be 0.00012721866049089135
# The point 144 had its second highest probability be 0.003175850104066334
# The point 145 had its second highest probability be 0.05444666008261923
# The point 146 had its second highest probability be 0.0020180977094165892
# The point 147 had its second highest probability be 0.16494610680228614
# The point 148 had its second highest probability be 0.00021930398708584875
# The point 149 had its second highest probability be 1.8800202540681427e-05
# The point 150 had its second highest probability be 0.025248472371034492
# The point 151 had its second highest probability be 4.984598280506133e-05
# The point 152 had its second highest probability be 0.00020023576331721694
# The point 153 had its second highest probability be 0.011182106696939599
# The point 154 had its second highest probability be 0.00021628740914429495
# The point 155 had its second highest probability be 3.1802618574244796e-05
# The point 156 had its second highest probability be 0.0006569888388824941
# The point 157 had its second highest probability be 0.0002132609989414634
# The point 158 had its second highest probability be 3.0787777264298885e-05
# The point 159 had its second highest probability be 2.365701146850524e-05
# The point 160 had its second highest probability be 4.675319454930888e-05
# The point 161 had its second highest probability be 0.0036795468147962735
# The point 162 had its second highest probability be 0.00017158436998067036
# The point 163 had its second highest probability be 0.00016779796875655598
# The point 164 had its second highest probability be 0.0001961784431377157
# The point 165 had its second highest probability be 0.0012684444465025395
# The point 166 had its second highest probability be 0.000782596311317357
# The point 167 had its second highest probability be 3.353806386499462e-05
# The point 168 had its second highest probability be 0.05105332712095893
# The point 169 had its second highest probability be 0.011692645042821534
# The point 170 had its second highest probability be 0.000583025763825839
# The point 171 had its second highest probability be 0.00034405698524485345
# The point 172 had its second highest probability be 3.3114842619897457e-06
# The point 173 had its second highest probability be 5.383211659775045e-05
# The point 174 had its second highest probability be 2.8674264890476656e-05
# The point 175 had its second highest probability be 0.021348740707063905
# The point 176 had its second highest probability be 0.0007652761688072671
# The point 177 had its second highest probability be 0.010868383008482056
# The point 178 had its second highest probability be 0.00028362606064119116
# The point 179 had its second highest probability be 0.22002034997811157
# The point 180 had its second highest probability be 0.0019513648078241619
# The point 181 had its second highest probability be 0.00034336439769967915
# The point 182 had its second highest probability be 0.0017801537117285782
# The point 183 had its second highest probability be 4.813478323194705e-06
# The point 184 had its second highest probability be 3.2973090923799024e-06
# The point 185 had its second highest probability be 0.04299451370463963
# The point 186 had its second highest probability be 0.00039938799545507803
# The point 187 had its second highest probability be 0.0014792574667015395
# The point 188 had its second highest probability be 0.0007056662103668804
# The point 189 had its second highest probability be 0.0026448232956217733
# The point 190 had its second highest probability be 0.02369903760637858
# The point 191 had its second highest probability be 6.169542083587744e-05
# The point 192 had its second highest probability be 0.008128783055603519
# The point 193 had its second highest probability be 0.0009172329588635241
# The point 194 had its second highest probability be 0.009105834668587436
# The point 195 had its second highest probability be 5.896946807432739e-05
# The point 196 had its second highest probability be 0.07205912836635586
# The point 197 had its second highest probability be 2.4140629044567723e-05
# The point 198 had its second highest probability be 0.013414393458274238
# The point 199 had its second highest probability be 2.325483611669339e-05
# The point 200 had its second highest probability be 0.0002750647200059118
# The point 201 had its second highest probability be 0.006807460468526581
# The point 202 had its second highest probability be 0.00016046661546990923
# The point 203 had its second highest probability be 0.018345120928206154
# The point 204 had its second highest probability be 0.000282843828619709
# The point 205 had its second highest probability be 0.0008085558857195464
# The point 206 had its second highest probability be 0.0005961044746448029
# The point 207 had its second highest probability be 0.0003898173657389176
# The point 208 had its second highest probability be 0.001504539555071253
# The point 209 had its second highest probability be 0.00043015777883920447
# The point 210 had its second highest probability be 1.1533319235621363e-05
# The point 211 had its second highest probability be 0.009202927852891687
# The point 212 had its second highest probability be 0.00948729173808142
# The point 213 had its second highest probability be 0.0008105825344473814
# The point 214 had its second highest probability be 0.06129829239821634
# The point 215 had its second highest probability be 0.0011032901070343157
# The point 216 had its second highest probability be 0.00026072950637489673
# The point 217 had its second highest probability be 0.000512733515820494
# The point 218 had its second highest probability be 4.494861169507017e-06
# The point 219 had its second highest probability be 0.0010180353426536613
# The point 220 had its second highest probability be 1.6899286889562093e-05
# The point 221 had its second highest probability be 0.0011823857313920164
# The point 222 had its second highest probability be 0.0028657464675895567
# The point 223 had its second highest probability be 0.0011334966526305931
# The point 224 had its second highest probability be 8.042572586251939e-05
# The point 225 had its second highest probability be 0.08463112903336342
# The point 226 had its second highest probability be 0.0002582779803190943
# The point 227 had its second highest probability be 6.497517499906455e-05
# The point 228 had its second highest probability be 0.00018757735007942551
# The point 229 had its second highest probability be 0.0009407810834587741
# The point 230 had its second highest probability be 0.0005262961302363869
# The point 231 had its second highest probability be 0.0005747850094786711
# The point 232 had its second highest probability be 0.00026782964929644867
# The point 233 had its second highest probability be 1.5472306920043136e-05
# The point 234 had its second highest probability be 0.040945234090143105
# The point 235 had its second highest probability be 0.3170160737830435
# The point 236 had its second highest probability be 0.10808137022125378
# The point 237 had its second highest probability be 0.00010590135523098318
# The point 238 had its second highest probability be 3.8374380615210914e-05
# The point 239 had its second highest probability be 0.007649336362329316
# The point 240 had its second highest probability be 0.11186298779401511
# The point 241 had its second highest probability be 0.19448052793894413
# The point 242 had its second highest probability be 7.001114833191059e-05
# The point 243 had its second highest probability be 0.005175226282929719
# The point 244 had its second highest probability be 0.0001516741097107587
# The point 245 had its second highest probability be 0.007039615363316317
# The point 246 had its second highest probability be 4.2956977323475824e-05
# The point 247 had its second highest probability be 0.001037213342105611
# The point 248 had its second highest probability be 0.0003915293176951019
# The point 249 had its second highest probability be 8.047898349264282e-06
# The point 250 had its second highest probability be 0.1673521135932038
# The point 251 had its second highest probability be 0.0004676143213872533
# The point 252 had its second highest probability be 0.0003410284320084024
# The point 253 had its second highest probability be 0.0026115753961798885
# The point 254 had its second highest probability be 6.104301023954847e-05
# The point 255 had its second highest probability be 0.00022295524839272332
# The point 256 had its second highest probability be 0.0005779082979002603
# The point 257 had its second highest probability be 8.303058243239094e-05
# The point 258 had its second highest probability be 0.007578120506757064
# The point 259 had its second highest probability be 0.0070130045605357235
# The point 260 had its second highest probability be 2.4700627745705327e-06
# The point 261 had its second highest probability be 0.0002374317772117387
# The point 262 had its second highest probability be 5.073884224405007e-05
# The point 263 had its second highest probability be 9.518369333393322e-05
# The point 264 had its second highest probability be 0.001822952412307555
# The point 265 had its second highest probability be 8.864255888473192e-05
# The point 266 had its second highest probability be 0.0001307088248901798
# The point 267 had its second highest probability be 0.00010140078904273036
# The point 268 had its second highest probability be 0.022982643842622018
# The point 269 had its second highest probability be 0.0005404776897823734
# The point 270 had its second highest probability be 0.00019033862120413579
# The point 271 had its second highest probability be 0.001001440646494166
# The point 272 had its second highest probability be 0.05798531955414073
# The point 273 had its second highest probability be 5.071499415900875e-05
# The point 274 had its second highest probability be 0.338138126194321
# The point 275 had its second highest probability be 0.0007366148986054283
# The point 276 had its second highest probability be 0.0021139482868245693
# The point 277 had its second highest probability be 0.006958083213628331
# The point 278 had its second highest probability be 0.0007576736426983128
# The point 279 had its second highest probability be 0.31874993726294854
# The point 280 had its second highest probability be 0.002259877226306263
# The point 281 had its second highest probability be 0.0001975855769219136
# The point 282 had its second highest probability be 0.12252856103759877
# The point 283 had its second highest probability be 3.5413171868446295e-05
# The point 284 had its second highest probability be 0.0001512310627858685
# The point 285 had its second highest probability be 0.0011146303065241094
# The point 286 had its second highest probability be 4.8812034258194656e-05
# The point 287 had its second highest probability be 5.006096364499604e-05
# The point 288 had its second highest probability be 0.0004989243846894888
# The point 289 had its second highest probability be 0.005868460699623771
# The point 290 had its second highest probability be 0.00036646923972362644
# The point 291 had its second highest probability be 0.00033266618552450864
# The point 292 had its second highest probability be 3.1739853272301103e-06
# The point 293 had its second highest probability be 0.0008180459521566403
# The point 294 had its second highest probability be 0.0002254581713883952
# The point 295 had its second highest probability be 0.0030408114315087723
# The point 296 had its second highest probability be 0.00018717853781941143
# The point 297 had its second highest probability be 0.20169259244479965
# The point 298 had its second highest probability be 0.009587900224599037
# The point 299 had its second highest probability be 0.002395868400373795
# The point 300 had its second highest probability be 0.002287340393312129
# The point 301 had its second highest probability be 1.7395688366749082e-05
# The point 302 had its second highest probability be 0.0014965964502129858
# The point 303 had its second highest probability be 0.008897264156689564
# The point 304 had its second highest probability be 3.812800590816859e-05
# The point 305 had its second highest probability be 1.4221196452789679e-06
# The point 306 had its second highest probability be 2.0610440506914566e-05
# The point 307 had its second highest probability be 4.573841504835685e-05
# The point 308 had its second highest probability be 6.754498182246098e-05
# The point 309 had its second highest probability be 0.24803752123553038
# The point 310 had its second highest probability be 0.01739438446057743
# The point 311 had its second highest probability be 0.0009931474522854864
# The point 312 had its second highest probability be 0.025134769601100632
# The point 313 had its second highest probability be 0.0011480988054168811
# The point 314 had its second highest probability be 0.003361550017088341
# The point 315 had its second highest probability be 0.0023609115476831023
# The point 316 had its second highest probability be 0.0005748561959738146
# The point 317 had its second highest probability be 0.0016404703739616529
# The point 318 had its second highest probability be 0.0005060745808785476
# The point 319 had its second highest probability be 9.590708515031183e-05
# The point 320 had its second highest probability be 0.0013435107864022103
# The point 321 had its second highest probability be 3.2269122751435385e-05
# The point 322 had its second highest probability be 0.004202172442536087
# The point 323 had its second highest probability be 0.0028136043290451006
# The point 324 had its second highest probability be 0.005366780195202069
# The point 325 had its second highest probability be 0.0008207208148867381
# The point 326 had its second highest probability be 0.0005140484226188221
# The point 327 had its second highest probability be 0.0012359509899150189
# The point 328 had its second highest probability be 0.0015447052156949337
# The point 329 had its second highest probability be 0.0162049003713447
# The point 330 had its second highest probability be 0.00040956691913670337
# The point 331 had its second highest probability be 0.0024284236642168368
# The point 332 had its second highest probability be 6.047157839382735e-06
# The point 333 had its second highest probability be 0.003312382337008072
# The point 334 had its second highest probability be 8.771377636519821e-05
# The point 335 had its second highest probability be 2.6660060904331422e-05
# The point 336 had its second highest probability be 4.3898281304742926e-05
# The point 337 had its second highest probability be 4.361569325809078e-05
# The point 338 had its second highest probability be 0.0017124682580455968
# The point 339 had its second highest probability be 0.00027672779994766675
# The point 340 had its second highest probability be 0.00021785095325122867
# The point 341 had its second highest probability be 0.00028223207161655274
# The point 342 had its second highest probability be 0.0012657929513764999
# The point 343 had its second highest probability be 0.3116834371234946
# The point 344 had its second highest probability be 0.007151818790542416
# The point 345 had its second highest probability be 0.00017466585812830313
# The point 346 had its second highest probability be 5.7700529132940554e-05
# The point 347 had its second highest probability be 0.037590137686363226
# The point 348 had its second highest probability be 0.00027605435572742904
# The point 349 had its second highest probability be 0.00072265888063793
# The point 350 had its second highest probability be 0.00012028938989661192
# The point 351 had its second highest probability be 0.0014679341243212394
# The point 352 had its second highest probability be 0.016560784055587658
# The point 353 had its second highest probability be 0.0018599077591167387
# The point 354 had its second highest probability be 4.737241312126863e-05
# The point 355 had its second highest probability be 0.007298021922901451
# The point 356 had its second highest probability be 0.06638343743921758
# The point 357 had its second highest probability be 0.009687430465513028
# The point 358 had its second highest probability be 0.0023158747355669675
# The point 359 had its second highest probability be 0.0001061591287536661
# The point 360 had its second highest probability be 0.00015086025487650218
# The point 361 had its second highest probability be 4.850713939878697e-05
# The point 362 had its second highest probability be 0.09221969750814708
# The point 363 had its second highest probability be 0.000887996604179567
# The point 364 had its second highest probability be 0.014393190917304568
# The point 365 had its second highest probability be 3.421469641379494e-05
# The point 366 had its second highest probability be 3.3928297098063e-05
# The point 367 had its second highest probability be 1.5482633476185562e-05
# The point 368 had its second highest probability be 0.001744566129040807
# The point 369 had its second highest probability be 0.05098952388545357
# The point 370 had its second highest probability be 0.0004814997295914567
# The point 371 had its second highest probability be 7.21018559017503e-05
# The point 372 had its second highest probability be 0.0007079129807897026
# The point 373 had its second highest probability be 1.1947156291066106e-07
# The point 374 had its second highest probability be 7.18268399204537e-05
# The point 375 had its second highest probability be 7.281346747260279e-05
# The point 376 had its second highest probability be 0.008848831934824542
# The point 377 had its second highest probability be 0.013568496446103471
# The point 378 had its second highest probability be 0.00016779384341212956
# The point 379 had its second highest probability be 6.732493312550894e-05
# The point 380 had its second highest probability be 0.0007550526136681721
# The point 381 had its second highest probability be 0.0009231056071493579
# The point 382 had its second highest probability be 5.063398904677086e-07
# The point 383 had its second highest probability be 0.008556169831778737
# The point 384 had its second highest probability be 0.007127209075840715
# The point 385 had its second highest probability be 6.771828692558348e-06
# The point 386 had its second highest probability be 3.175641746499218e-06
# The point 387 had its second highest probability be 0.00033664790107156223
# The point 388 had its second highest probability be 8.947005306917043e-06
# The point 389 had its second highest probability be 0.007090476083377457
# The point 390 had its second highest probability be 5.941110775175726e-05
# The point 391 had its second highest probability be 0.008893731352417245
# The point 392 had its second highest probability be 0.0007174490075482781
# The point 393 had its second highest probability be 0.00011511092251303397
# The point 394 had its second highest probability be 0.00012111134341525996
# The point 395 had its second highest probability be 0.005839945590430763
# The point 396 had its second highest probability be 0.0003442904221466045
# The point 397 had its second highest probability be 0.02798103380360286
# The point 398 had its second highest probability be 0.001149056289508627
# The point 399 had its second highest probability be 0.0005143171922199193
# The point 400 had its second highest probability be 0.0013825361926003542
# The point 401 had its second highest probability be 0.0007030944302257376
# The point 402 had its second highest probability be 0.0012443930833023497
# The point 403 had its second highest probability be 0.013609019612560105
# The point 404 had its second highest probability be 0.0004968960573875959
# The point 405 had its second highest probability be 0.008006211810730971
# The point 406 had its second highest probability be 7.435262963060579e-05
# The point 407 had its second highest probability be 0.0011003354205476182
# The point 408 had its second highest probability be 2.575592959051115e-05
# The point 409 had its second highest probability be 0.00015919023607631214
# The point 410 had its second highest probability be 0.0031677062162616064
# The point 411 had its second highest probability be 0.0013519256654357268
# The point 412 had its second highest probability be 0.002451562159935316
# The point 413 had its second highest probability be 0.00023692542752770435
# The point 414 had its second highest probability be 0.20543214329111864
# The point 415 had its second highest probability be 0.015253999246989475
# The point 416 had its second highest probability be 0.005611859234373719
# The point 417 had its second highest probability be 0.005712574838894352
# The point 418 had its second highest probability be 0.029955399978122903
# The point 419 had its second highest probability be 0.0023556916761872386
# The point 420 had its second highest probability be 0.003804152811015222
# The point 421 had its second highest probability be 0.0005380138249766305
# The point 422 had its second highest probability be 0.0007111770996870778
# The point 423 had its second highest probability be 0.005533844877254562
# The point 424 had its second highest probability be 0.0003009502128200178
# The point 425 had its second highest probability be 0.028017730673184034
# The point 426 had its second highest probability be 0.006409033963641174
# The point 427 had its second highest probability be 0.00786935333303883
# The point 428 had its second highest probability be 0.0002891896037965638
# The point 429 had its second highest probability be 0.00579367845314282
# The point 430 had its second highest probability be 0.0004451965539747064
# The point 431 had its second highest probability be 0.018255765299378637
# The point 432 had its second highest probability be 0.010456514077908792
# The point 433 had its second highest probability be 0.00013949086428697243
# The point 434 had its second highest probability be 0.0020745812160905147
# The point 435 had its second highest probability be 0.0006386365106617854
# The point 436 had its second highest probability be 0.00016995327766961105
# The point 437 had its second highest probability be 0.005629767854292344
# The point 438 had its second highest probability be 0.009678975673034315
# The point 439 had its second highest probability be 0.0021850891604283202
# The point 440 had its second highest probability be 0.0001359935281070366
# The point 441 had its second highest probability be 0.0007626879592698611
# The point 442 had its second highest probability be 6.803091402609765e-05
# The point 443 had its second highest probability be 6.077402059553995e-05
# The point 444 had its second highest probability be 0.0002122457960587267
# The point 445 had its second highest probability be 0.022734923063587435
# The point 446 had its second highest probability be 1.2089897062050722e-07
# The point 447 had its second highest probability be 0.20520008728164232
# The point 448 had its second highest probability be 0.00030632936135955815
# The point 449 had its second highest probability be 0.0002896442350442825
# The point 450 had its second highest probability be 0.00021920489778608275
# The point 451 had its second highest probability be 0.0002082708583821813
# The point 452 had its second highest probability be 0.000333792018331591
# The point 453 had its second highest probability be 1.839474445606862e-05
# The point 454 had its second highest probability be 0.010938975549626468
# The point 455 had its second highest probability be 0.0034283265492691295
# The point 456 had its second highest probability be 0.003901231512851473
# The point 457 had its second highest probability be 0.0010459526359396065
# The point 458 had its second highest probability be 0.00015258185653778189
# The point 459 had its second highest probability be 0.00046851539716667804
# The point 460 had its second highest probability be 3.698868529853281e-05
# The point 461 had its second highest probability be 0.00013702650481465451
# The point 462 had its second highest probability be 0.00042361978350829006
# The point 463 had its second highest probability be 0.0014577891910418327
# The point 464 had its second highest probability be 0.020248052198766065
# The point 465 had its second highest probability be 0.00486002114115623
# The point 466 had its second highest probability be 4.8666676422861704e-05
# The point 467 had its second highest probability be 0.0037571095381653996
# The point 468 had its second highest probability be 0.02324922028809773
# The point 469 had its second highest probability be 0.00021323736965782856
# The point 470 had its second highest probability be 0.11829651711658729
# The point 471 had its second highest probability be 0.0009057493216630853
# The point 472 had its second highest probability be 0.48426431944382947
# The point 473 had its second highest probability be 6.392343188891892e-05
# The point 474 had its second highest probability be 4.055120189116028e-05
# The point 475 had its second highest probability be 0.0013850893882187455
# The point 476 had its second highest probability be 0.0008758519236888852
# The point 477 had its second highest probability be 0.005528609818976809
# The point 478 had its second highest probability be 0.00019979904684665548
# The point 479 had its second highest probability be 0.0014128132354382663
# The point 480 had its second highest probability be 0.0007069315132516985
# The point 481 had its second highest probability be 0.050984354465451784
# The point 482 had its second highest probability be 0.0003592948237971628
# The point 483 had its second highest probability be 0.0005524587680697133
# The point 484 had its second highest probability be 0.0010385835211486742
# The point 485 had its second highest probability be 1.1154941118631802e-06
# The point 486 had its second highest probability be 0.0013907497125230832
# The point 487 had its second highest probability be 1.8083496077700192e-06
# The point 488 had its second highest probability be 4.426346044285158e-05
# The point 489 had its second highest probability be 0.0012182682596684061
# The point 490 had its second highest probability be 0.00018348865697548285
# The point 491 had its second highest probability be 1.6600515849405408e-05
# The point 492 had its second highest probability be 0.06955720204645499
# The point 493 had its second highest probability be 0.0009116810764601902
# The point 494 had its second highest probability be 0.003503520040836495
# The point 495 had its second highest probability be 0.0002586171004032655
# The point 496 had its second highest probability be 0.011317610847175905
# The point 497 had its second highest probability be 0.29302546059231993
# The point 498 had its second highest probability be 0.0006918299490597924
# The point 499 had its second highest probability be 0.00012458269331747825
# The point 500 had its second highest probability be 0.00042122215318989465
# The point 501 had its second highest probability be 3.151305298213519e-05
# The point 502 had its second highest probability be 0.0006111610936710371
# The point 503 had its second highest probability be 4.1070806003021295e-05
# The point 504 had its second highest probability be 0.0002843128538195002
# The point 505 had its second highest probability be 0.0010167213331816532
# The point 506 had its second highest probability be 0.0034629197038416643
# The point 507 had its second highest probability be 4.96850075963432e-05
# The point 508 had its second highest probability be 0.009674883092489161
# The point 509 had its second highest probability be 0.0006081721825258807
# The point 510 had its second highest probability be 0.00017178401694883293
# The point 511 had its second highest probability be 0.09812259486295387
# The point 512 had its second highest probability be 0.4261580332898342
# The point 513 had its second highest probability be 3.1539091223610945e-05
# The point 514 had its second highest probability be 0.0013274001158348659
# The point 515 had its second highest probability be 0.19890505189364716
# The point 516 had its second highest probability be 0.0002940704214823737
# The point 517 had its second highest probability be 0.0032575982961510963
# The point 518 had its second highest probability be 0.00866285679429432
# The point 519 had its second highest probability be 2.656001896011232e-05
# The point 520 had its second highest probability be 0.00042157077434651114
# The point 521 had its second highest probability be 9.021690335900918e-05
# The point 522 had its second highest probability be 0.0806875560966757
# The point 523 had its second highest probability be 5.625923590363989e-05
# The point 524 had its second highest probability be 0.16376196371279772
# The point 525 had its second highest probability be 5.471733201211035e-06
# The point 526 had its second highest probability be 0.0004345931051391065
# The point 527 had its second highest probability be 0.0004150247376974689
# The point 528 had its second highest probability be 4.1705448175250704e-05
# The point 529 had its second highest probability be 0.00660058841227331
# The point 530 had its second highest probability be 4.531951265724458e-05
# The point 531 had its second highest probability be 0.0030086061267057588
# The point 532 had its second highest probability be 0.4708236474197984
# The point 533 had its second highest probability be 0.07267782955768762
# The point 534 had its second highest probability be 0.005878666370930636
# The point 535 had its second highest probability be 0.0001181611086207547
# The point 536 had its second highest probability be 6.46252299659018e-06
# The point 537 had its second highest probability be 5.944199487268077e-05
# The point 538 had its second highest probability be 0.12567263194441483
# The point 539 had its second highest probability be 0.060953761184847986
# The point 540 had its second highest probability be 4.970703912457294e-05
# The point 541 had its second highest probability be 0.0034230823281226593
# The point 542 had its second highest probability be 0.0018311388612505775
# The point 543 had its second highest probability be 0.00041345495064619913
# The point 544 had its second highest probability be 1.2653925834928981e-05
# The point 545 had its second highest probability be 0.0606391754800877
# The point 546 had its second highest probability be 0.09836985187310186
# The point 547 had its second highest probability be 0.0030854120214536657
# The point 548 had its second highest probability be 0.008024568731086795
# The point 549 had its second highest probability be 0.001751681722385683
# The point 550 had its second highest probability be 0.00023219375848081933
# The point 551 had its second highest probability be 0.14269316914473876
# The point 552 had its second highest probability be 0.001998741167414628
# The point 553 had its second highest probability be 0.0001451510601444494
# The point 554 had its second highest probability be 0.00011717993948945026
# The point 555 had its second highest probability be 2.6714195208012605e-05
# The point 556 had its second highest probability be 2.5337886706032592e-05
# The point 557 had its second highest probability be 0.0018217851981948091
# The point 558 had its second highest probability be 0.04207894913182058
# The point 559 had its second highest probability be 4.876086936396461e-05
# The point 560 had its second highest probability be 0.00027306621497148503
# The point 561 had its second highest probability be 0.000104386522388043
# The point 562 had its second highest probability be 0.0007356408771818599
# The point 563 had its second highest probability be 0.0018300854569527163
# The point 564 had its second highest probability be 0.0003922697130684265
# The point 565 had its second highest probability be 1.2650045110858922e-06
# The point 566 had its second highest probability be 0.0005308564071809778
# The point 567 had its second highest probability be 0.0028848417848525137
# The point 568 had its second highest probability be 7.321785082979605e-05
# The point 569 had its second highest probability be 0.002152523383037819
# The point 570 had its second highest probability be 0.0091812938446243
# The point 571 had its second highest probability be 0.034320112110701996
# The point 572 had its second highest probability be 2.1312946740445604e-05
# The point 573 had its second highest probability be 0.00020934435487594908
# The point 574 had its second highest probability be 0.002092348185470656
# The point 575 had its second highest probability be 2.943393676331901e-05
# The point 576 had its second highest probability be 0.21000304711546977
# The point 577 had its second highest probability be 0.00024000517158592117
# The point 578 had its second highest probability be 0.0007153880766127887
# The point 579 had its second highest probability be 0.0021416969889781617
# The point 580 had its second highest probability be 0.00101587577986548
# The point 581 had its second highest probability be 0.00035507146690181256
# The point 582 had its second highest probability be 0.000952899369580799
# The point 583 had its second highest probability be 8.696741296441144e-05
# The point 584 had its second highest probability be 0.0009379522991761877
# The point 585 had its second highest probability be 0.0008603735929149698
# The point 586 had its second highest probability be 5.0954678665620264e-05
# The point 587 had its second highest probability be 0.0006180639450997832
# The point 588 had its second highest probability be 0.001670445803939839
# The point 589 had its second highest probability be 0.0012268949803519863
# The point 590 had its second highest probability be 0.0005847071714455794
# The point 591 had its second highest probability be 0.24580726333052547
# The point 592 had its second highest probability be 0.03745170209961273
# The point 593 had its second highest probability be 6.268091847770522e-05
# The point 594 had its second highest probability be 9.508092636899466e-05
# The point 595 had its second highest probability be 0.0003008641660513973
# The point 596 had its second highest probability be 0.0001878236766519894
# The point 597 had its second highest probability be 4.697654388255208e-05
# The point 598 had its second highest probability be 0.00027311362321296215
# The point 599 had its second highest probability be 0.0005594215436105066
# The point 600 had its second highest probability be 0.0001468360003736604
# The point 601 had its second highest probability be 2.1075906984074407e-05
# The point 602 had its second highest probability be 0.26548855691092715
# The point 603 had its second highest probability be 0.0004989795428630657
# The point 604 had its second highest probability be 0.00016376550404741659
# The point 605 had its second highest probability be 0.0016719130945923276
# The point 606 had its second highest probability be 4.005409369702358e-05
# The point 607 had its second highest probability be 0.0005185152601901188
# The point 608 had its second highest probability be 0.001808245518430258
# The point 609 had its second highest probability be 3.5127709187321327e-05
# The point 610 had its second highest probability be 4.4709698717573785e-05
# The point 611 had its second highest probability be 0.04543471966297247
# The point 612 had its second highest probability be 0.00010241003751976235
# The point 613 had its second highest probability be 0.0012374475176869487
# The point 614 had its second highest probability be 0.0038380332738858942
# The point 615 had its second highest probability be 0.00031458468134449967
# The point 616 had its second highest probability be 0.0009199152083310077
# The point 617 had its second highest probability be 0.18286523907904753
# The point 618 had its second highest probability be 0.0006392734631987906
# The point 619 had its second highest probability be 0.0024556899562462276
# The point 620 had its second highest probability be 0.0001653513072558189
# The point 621 had its second highest probability be 5.283123547315597e-05
# The point 622 had its second highest probability be 0.04102860708584866
# The point 623 had its second highest probability be 0.040376741957561225
# The point 624 had its second highest probability be 0.004800331106742609
# The point 625 had its second highest probability be 1.4811859653488266e-05
# The point 626 had its second highest probability be 1.694451484802597e-05
# The point 627 had its second highest probability be 0.001367894607268751
# The point 628 had its second highest probability be 0.0008185222965134799
# The point 629 had its second highest probability be 1.8091949095085424e-05
# The point 630 had its second highest probability be 0.005800536697620067
# The point 631 had its second highest probability be 0.0001753714330824813
# The point 632 had its second highest probability be 0.03838936578236666
# The point 633 had its second highest probability be 0.00034643275632265585
# The point 634 had its second highest probability be 0.11202213483197904
# The point 635 had its second highest probability be 2.498327435779313e-06
# The point 636 had its second highest probability be 0.0022597131402706553
# The point 637 had its second highest probability be 2.0875803860586266e-05
# The point 638 had its second highest probability be 0.013536102800456256
# The point 639 had its second highest probability be 0.003643751956009455
# The point 640 had its second highest probability be 0.010081733301575435
# The point 641 had its second highest probability be 0.008147541322573863
# The point 642 had its second highest probability be 0.0889101372571053
# The point 643 had its second highest probability be 0.003209077852482896
# The point 644 had its second highest probability be 0.00041698146258312596
# The point 645 had its second highest probability be 0.0018389519483365852
# The point 646 had its second highest probability be 0.005592428130146937
# The point 647 had its second highest probability be 2.0340324740258418e-05
# The point 648 had its second highest probability be 0.0004590035653244911
# The point 649 had its second highest probability be 0.0036036015730433663
# The point 650 had its second highest probability be 0.0004878192807395892
# The point 651 had its second highest probability be 0.0005666537271498791
# ...
# The point 9786 had its second highest probability be 0.0012048937271890614
# The point 9787 had its second highest probability be 2.158856303540156e-05
# The point 9788 had its second highest probability be 0.0010772627797175727
# The point 9789 had its second highest probability be 0.10801741726275957
# The point 9790 had its second highest probability be 0.012242378305815387
# The point 9791 had its second highest probability be 0.0030296443534676555
# The point 9792 had its second highest probability be 0.013134164121283893
# The point 9793 had its second highest probability be 0.00042390309397137983
# The point 9794 had its second highest probability be 0.0001694349441877306
# The point 9795 had its second highest probability be 0.002164923060594931
# The point 9796 had its second highest probability be 0.0003173994130067892
# The point 9797 had its second highest probability be 0.05230988863595459
# The point 9798 had its second highest probability be 1.9756781243156805e-05
# The point 9799 had its second highest probability be 0.005059805035062054
# The point 9800 had its second highest probability be 0.00014473751630326604
# The point 9801 had its second highest probability be 1.647264865572749e-05
# The point 9802 had its second highest probability be 0.003671142083949932
# The point 9803 had its second highest probability be 0.0014952080005357592
# The point 9804 had its second highest probability be 0.001112022637230047
# The point 9805 had its second highest probability be 0.0319668789519822
# The point 9806 had its second highest probability be 0.03616401860902146
# The point 9807 had its second highest probability be 0.0011064960704252737
# The point 9808 had its second highest probability be 0.000331650684752253
# The point 9809 had its second highest probability be 0.00011759525275535433
# The point 9810 had its second highest probability be 0.001024678499159777
# The point 9811 had its second highest probability be 0.012779283186648675
# The point 9812 had its second highest probability be 0.000567560343342249
# The point 9813 had its second highest probability be 0.0006025576477927421
# The point 9814 had its second highest probability be 0.00018412571678444085
# The point 9815 had its second highest probability be 0.05331328461984517
# The point 9816 had its second highest probability be 0.0006657322989618713
# The point 9817 had its second highest probability be 0.4060413615647423
# The point 9818 had its second highest probability be 0.0004733407291103189
# The point 9819 had its second highest probability be 0.00031264225816984143
# The point 9820 had its second highest probability be 0.0013910846635290383
# The point 9821 had its second highest probability be 0.106956934815413
# The point 9822 had its second highest probability be 0.0006436295118860588
# The point 9823 had its second highest probability be 0.010883898091287729
# The point 9824 had its second highest probability be 0.0011635566092668412
# The point 9825 had its second highest probability be 0.004569322891188025
# The point 9826 had its second highest probability be 7.572440568605137e-05
# The point 9827 had its second highest probability be 0.2356699851676073
# The point 9828 had its second highest probability be 0.004125740422624556
# The point 9829 had its second highest probability be 2.7854035422394633e-05
# The point 9830 had its second highest probability be 9.579976380009835e-05
# The point 9831 had its second highest probability be 2.600582088763984e-05
# The point 9832 had its second highest probability be 0.0002462121002899399
# The point 9833 had its second highest probability be 0.42505196482253177
# The point 9834 had its second highest probability be 3.316754322449618e-05
# The point 9835 had its second highest probability be 0.004751933780642832
# The point 9836 had its second highest probability be 0.04749412319945256
# The point 9837 had its second highest probability be 0.0061258013561769666
# The point 9838 had its second highest probability be 0.0007067145332411964
# The point 9839 had its second highest probability be 0.00028596407728172853
# The point 9840 had its second highest probability be 0.41969080538509
# The point 9841 had its second highest probability be 6.329444288673757e-05
# The point 9842 had its second highest probability be 2.015196259373663e-05
# The point 9843 had its second highest probability be 8.149056812863342e-05
# The point 9844 had its second highest probability be 0.010136893498996024
# The point 9845 had its second highest probability be 0.001044333039947602
# The point 9846 had its second highest probability be 1.2278462599491101e-05
# The point 9847 had its second highest probability be 0.0005611785953811073
# The point 9848 had its second highest probability be 0.00015032965528449923
# The point 9849 had its second highest probability be 0.0008111926490723658
# The point 9850 had its second highest probability be 0.002581087170443738
# The point 9851 had its second highest probability be 0.0015934145937693915
# The point 9852 had its second highest probability be 0.0005555550364836571
# The point 9853 had its second highest probability be 0.00018819217333105782
# The point 9854 had its second highest probability be 0.00028014376118797615
# The point 9855 had its second highest probability be 0.004006466268056647
# The point 9856 had its second highest probability be 0.0010222778747491393
# The point 9857 had its second highest probability be 0.000658134219811829
# The point 9858 had its second highest probability be 0.0026341221292476465
# The point 9859 had its second highest probability be 6.068173046987078e-06
# The point 9860 had its second highest probability be 0.00041334558878891136
# The point 9861 had its second highest probability be 0.00014912211811651856
# The point 9862 had its second highest probability be 0.0025989651234546805
# The point 9863 had its second highest probability be 0.009163998175580206
# The point 9864 had its second highest probability be 0.00010845552040241923
# The point 9865 had its second highest probability be 0.0021472734536630155
# The point 9866 had its second highest probability be 0.0032894393627628136
# The point 9867 had its second highest probability be 0.0041134745940951106
# The point 9868 had its second highest probability be 0.00012882762978816244
# The point 9869 had its second highest probability be 0.00011246122858689943
# The point 9870 had its second highest probability be 0.00022174903933923945
# The point 9871 had its second highest probability be 0.015045149724505463
# The point 9872 had its second highest probability be 4.342570052971562e-05
# The point 9873 had its second highest probability be 0.0004672887097435064
# The point 9874 had its second highest probability be 0.00031737375834608235
# The point 9875 had its second highest probability be 6.202401938530403e-05
# The point 9876 had its second highest probability be 0.010290041119690245
# The point 9877 had its second highest probability be 0.0008924579598786819
# The point 9878 had its second highest probability be 0.0005743774906070725
# The point 9879 had its second highest probability be 6.236731599977567e-07
# The point 9880 had its second highest probability be 0.018355978901954718
# The point 9881 had its second highest probability be 0.21982926347367507
# The point 9882 had its second highest probability be 0.0009235833194145132
# The point 9883 had its second highest probability be 0.06127428668692187
# The point 9884 had its second highest probability be 0.00010031613033147179
# The point 9885 had its second highest probability be 0.0003084571154483245
# The point 9886 had its second highest probability be 4.077352589943885e-05
# The point 9887 had its second highest probability be 0.04930183167831169
# The point 9888 had its second highest probability be 2.158639887877819e-05
# The point 9889 had its second highest probability be 0.00010194016086670727
# The point 9890 had its second highest probability be 0.0007769048684635314
# The point 9891 had its second highest probability be 0.0002286603391376096
# The point 9892 had its second highest probability be 0.00021964053570155953
# The point 9893 had its second highest probability be 0.00023950597286003094
# The point 9894 had its second highest probability be 0.0034365946322314636
# The point 9895 had its second highest probability be 0.0008868671610926827
# The point 9896 had its second highest probability be 0.0003870237549822019
# The point 9897 had its second highest probability be 0.18707283822085014
# The point 9898 had its second highest probability be 6.8587846001978655e-06
# The point 9899 had its second highest probability be 0.0003716584809199772
# The point 9900 had its second highest probability be 0.031065696806094705
# The point 9901 had its second highest probability be 3.302039025947342e-05
# The point 9902 had its second highest probability be 0.0003978126592314201
# The point 9903 had its second highest probability be 0.009341149274233171
# The point 9904 had its second highest probability be 0.0042728717436077085
# The point 9905 had its second highest probability be 7.946661686661066e-05
# The point 9906 had its second highest probability be 0.00020237125171703872
# The point 9907 had its second highest probability be 0.0017577212143163746
# The point 9908 had its second highest probability be 0.001487361861063722
# The point 9909 had its second highest probability be 0.0003683177595993957
# The point 9910 had its second highest probability be 0.0013592407623126976
# The point 9911 had its second highest probability be 0.003237851665678097
# The point 9912 had its second highest probability be 0.000381068341979666
# The point 9913 had its second highest probability be 0.0005421558897704353
# The point 9914 had its second highest probability be 0.0009165609545228459
# The point 9915 had its second highest probability be 0.0001793925949877186
# The point 9916 had its second highest probability be 0.0020895004501868025
# The point 9917 had its second highest probability be 0.22196843462962393
# The point 9918 had its second highest probability be 0.00010500750867588023
# The point 9919 had its second highest probability be 0.0008680671772572971
# The point 9920 had its second highest probability be 0.0008124354978870684
# The point 9921 had its second highest probability be 0.00071961568735226
# The point 9922 had its second highest probability be 0.00025029119628668025
# The point 9923 had its second highest probability be 0.001027145369059768
# The point 9924 had its second highest probability be 0.0008672545989360201
# The point 9925 had its second highest probability be 4.510314698668625e-05
# The point 9926 had its second highest probability be 0.15349646894592747
# The point 9927 had its second highest probability be 8.502006328300493e-05
# The point 9928 had its second highest probability be 0.003353709441465102
# The point 9929 had its second highest probability be 0.01669583393970721
# The point 9930 had its second highest probability be 0.007235820335568974
# The point 9931 had its second highest probability be 0.0005304845512656128
# The point 9932 had its second highest probability be 0.008197294845731071
# The point 9933 had its second highest probability be 5.822329517785225e-05
# The point 9934 had its second highest probability be 0.00160166072153454
# The point 9935 had its second highest probability be 0.0013261300383737205
# The point 9936 had its second highest probability be 0.00031643015182886825
# The point 9937 had its second highest probability be 0.00012975737719143803
# The point 9938 had its second highest probability be 0.00025458288377270513
# The point 9939 had its second highest probability be 1.6168070301566667e-05
# The point 9940 had its second highest probability be 0.014558759873204388
# The point 9941 had its second highest probability be 0.21458919079578886
# The point 9942 had its second highest probability be 3.4498323608060595e-06
# The point 9943 had its second highest probability be 0.0040648431994463425
# The point 9944 had its second highest probability be 0.00020125331897761294
# The point 9945 had its second highest probability be 0.0019081207589751697
# The point 9946 had its second highest probability be 0.35284045197436825
# The point 9947 had its second highest probability be 0.004632388514070126
# The point 9948 had its second highest probability be 4.56562323376887e-06
# The point 9949 had its second highest probability be 4.364054245734077e-06
# The point 9950 had its second highest probability be 2.890131100891695e-06
# The point 9951 had its second highest probability be 8.118098651021818e-05
# The point 9952 had its second highest probability be 0.013822818292731116
# The point 9953 had its second highest probability be 0.00014618360308781803
# The point 9954 had its second highest probability be 0.16280668207735502
# The point 9955 had its second highest probability be 0.0011374661369733378
# The point 9956 had its second highest probability be 6.949298810103691e-05
# The point 9957 had its second highest probability be 0.00019843366298551076
# The point 9958 had its second highest probability be 0.0242908788434579
# The point 9959 had its second highest probability be 0.011800940321235465
# The point 9960 had its second highest probability be 0.00041716632408891945
# The point 9961 had its second highest probability be 0.00024226821545688507
# The point 9962 had its second highest probability be 0.000903699034762849
# The point 9963 had its second highest probability be 0.001476359783885298
# The point 9964 had its second highest probability be 0.0002708904333070837
# The point 9965 had its second highest probability be 0.036985308574011715
# The point 9966 had its second highest probability be 7.156760470955428e-05
# The point 9967 had its second highest probability be 4.5206847266250235e-05
# The point 9968 had its second highest probability be 9.231328876131951e-05
# The point 9969 had its second highest probability be 1.6269480115737242e-06
# The point 9970 had its second highest probability be 0.00021371146935973188
# The point 9971 had its second highest probability be 0.005740769552148513
# The point 9972 had its second highest probability be 0.0004815992150088813
# The point 9973 had its second highest probability be 0.0011079977158291148
# The point 9974 had its second highest probability be 0.14434374140742987
# The point 9975 had its second highest probability be 0.05591342122388588
# The point 9976 had its second highest probability be 0.0014127157198724474
# The point 9977 had its second highest probability be 0.0023174097918975205
# The point 9978 had its second highest probability be 0.08113041002802347
# The point 9979 had its second highest probability be 0.023837325971216954
# The point 9980 had its second highest probability be 0.06022465652264252
# The point 9981 had its second highest probability be 8.217321448860476e-06
# The point 9982 had its second highest probability be 0.1365703359168903
# The point 9983 had its second highest probability be 0.021908405421334452
# The point 9984 had its second highest probability be 0.0002696276690952237
# The point 9985 had its second highest probability be 9.274610136412332e-06
# The point 9986 had its second highest probability be 8.416280078086031e-05
# The point 9987 had its second highest probability be 0.009323708584748269
# The point 9988 had its second highest probability be 0.0014627194190700926
# The point 9989 had its second highest probability be 0.0004486553843659774
# The point 9990 had its second highest probability be 0.0015117319756579933
# The point 9991 had its second highest probability be 9.509488091269733e-05
# The point 9992 had its second highest probability be 2.491686388317058e-05
# The point 9993 had its second highest probability be 0.0007654635659546072
# The point 9994 had its second highest probability be 0.01266990368746298
# The point 9995 had its second highest probability be 0.04435671535528484
# The point 9996 had its second highest probability be 0.004653789055600694
# The point 9997 had its second highest probability be 3.401012400436484e-05
# The point 9998 had its second highest probability be 0.003154755211768754
# The point 9999 had its second highest probability be 0.0007628025098688401

# %% [markdown]
# **Q0-2**: For each data point misclassified by the model, find if the second best prediction is actually the correct label. Calculate the percentage of missclassified points, that are correctly classified based on the second best prediction. [10 pts]

# %%
### Your code here. Also give some comments about your findings
# We are comparing the predictions with the y test
mismatch = 0
index_of_mismatch_ytest = []
for i in range(len(predictions)):
    if(predictions[i]==y_test.iloc[i]):
        continue
    else:
        mismatch += 1
        index_of_mismatch_ytest.append(i)
        #store the label index into an array of y_test
        continue
mismatch_percent = mismatch/10000
print(f"There are {mismatch} labels that are missclassified from y_test meaning that {mismatch_percent}% of the y_pred are missclassified points")
print("Now checking if the second highest predictions is the correct label")
#retrieving index of value
def ind(array, item):
    for idx, val in np.ndenumerate(array):
        if val == item:
            return idx
#print(index_of_mismatch)
sec_prob_corr = 0
for i in index_of_mismatch_ytest:
    arr = probability_predictions[i].copy()
    arr.sort()
    prob2 = arr[-2] #returns the value of the second highest prob
    #prob2 = prob2.astype(int)
    prob2_indx = ind(probability_predictions[i],prob2)
    if int(prob2_indx[0]) == y_test.iloc[i]:
        sec_prob_corr+=1
print(f"The number of correctly classified lables as the second highest probablity is {sec_prob_corr} points")
print(f"The percentage of missclassified points that are correctly classifed as the second highest probability is {sec_prob_corr/mismatch}%")
# Out:
# There are 315 labels that are missclassified from y_test meaning that 0.0315% of the y_pred are missclassified points
# Now checking if the second highest predictions is the correct label
# The number of correctly classified lables as the second highest probablity is 210 points
# The percentage of missclassified points that are correctly classifed as the second highest probability is 0.6666666666666666%

# %% [markdown]
# **Q0-3**: From a human point of view, we can perhaps see a frequent similarity between handritten digits 3 and 5 (i.e. sometimes we have to pay closer attention to figure out what the true written digit is). We may want to ask if the MLP also detects digit similarities.
# <br>
#  Consider then the subset $X_i$ of data points that have label $i$ (e.g. all data points with label 5). For each label $j\neq i$, report the frequency by which label $j$ (e.g. label 3) shows up as second best prediction for points in $X_i$. [10 pts]
# <br>
# <br>
# ***Further Clarification***: Suppose we have 100 data points with label i=5. Let's say that for 28 of these 100 points, the second predicted label is j=3. Then, the frequency of j=3 as second-best prediction to i=5 is 28%.  We want to compute that frequency for every i and j.
#
# Example output:
# > i = 0: 986 (9.86%)
#
#   j = 1: 2 (0.203%)
#
#   j = 2: 248 (25.152%)
#
#   j = 3: 8 (0.811%)
#
#   j = 4: 4 (0.406%)
#
#   j = 5: 270 (27.383%)
#
#   j = 6: 188 (19.067%)
#
#   j = 7: 56 (5.68%)
#
#   j = 8: 52 (5.274%)
#
#   j = 9: 150 (15.213%)
#
# <br>
#  Give your code and comment on your findings

# %%
# Your code here. Also give some comments about your findings
# find all labels that have predicted 5 and then check what labels have appeared to be the second highest probability
label = 5
index_of_5 = []
num_label_0 = 0
num_label_1 = 0
num_label_2 = 0
num_label_3 = 0
num_label_4 = 0
num_label_5 = 0
num_label_6 = 0
num_label_7 = 0
num_label_8 = 0
num_label_9 = 0
for i in range(len(y_test)):
    if y_test.iloc[i] == label:
        index_of_5.append(i)
total = len(index_of_5)
print(f"Number of arrays that have been labeled 5: {len(index_of_5)}")

for i in index_of_5:
    arr = probability_predictions[i].copy()
    arr.sort()
    prob2 = arr[-2]
    prob2_indx = ind(probability_predictions[i], prob2)
    
    if int(prob2_indx[0]) == 0:
        num_label_0 += 1
    elif int(prob2_indx[0]) == 1:
        num_label_1 += 1
    elif int(prob2_indx[0]) == 2:
        num_label_2 += 1
    elif int(prob2_indx[0]) == 3:
        num_label_3 += 1
    elif int(prob2_indx[0]) == 4:
        num_label_4 += 1
    elif int(prob2_indx[0]) == 5:
        num_label_5 += 1
    elif int(prob2_indx[0]) == 6:
        num_label_6 += 1
    elif int(prob2_indx[0]) == 7:
        num_label_7 += 1
    elif int(prob2_indx[0]) == 8:
        num_label_8 += 1
    elif int(prob2_indx[0]) == 9:
        num_label_9 += 1

print("This the frequency of label 0 being second highest probabilty: ",num_label_0/total)
print("This the frequency of label 1 being second highest probabilty: ",num_label_1/total)
print("This the frequency of label 2 being second highest probabilty: ",num_label_2/total)
print("This the frequency of label 3 being second highest probabilty: ",num_label_3/total)
print("This the frequency of label 4 being second highest probabilty: ",num_label_4/total)  
print("This the frequency of label 6 being second highest probabilty: ",num_label_6/total)
print("This the frequency of label 7 being second highest probabilty: ",num_label_7/total)
print("This the frequency of label 8 being second highest probabilty: ",num_label_8/total)
print("This the frequency of label 9 being second highest probabilty: ",num_label_9/total)
print("We can see highest frequency is for label 3")
# Out:
# Number of arrays that have been labeled 5: 902
# This the frequency of label 0 being second highest probabilty:  0.082039911308204
# This the frequency of label 1 being second highest probabilty:  0.06430155210643015
# This the frequency of label 2 being second highest probabilty:  0.018847006651884702
# This the frequency of label 3 being second highest probabilty:  0.37915742793791574
# This the frequency of label 4 being second highest probabilty:  0.041019955654102
# This the frequency of label 6 being second highest probabilty:  0.07317073170731707
# This the frequency of label 7 being second highest probabilty:  0.011086474501108648
# This the frequency of label 8 being second highest probabilty:  0.18736141906873613
# This the frequency of label 9 being second highest probabilty:  0.11529933481152993
# We can see highest frequency is for label 3

# %%
# For grader use only



maxScore = maxScore + 40

# %% [markdown]
# ------------------------------
# ------------------------------
# ------------------------------

# %% [markdown]
# ## <font color='blue'>Question 1: Working with warm start for focused training [10 pts by 4 = 40 pts]

# %% [markdown]
# **Q1-0**. MLP classifiers in scikit-learn have an option for so-called 'warm start'. Do a bit of research to find out what it is. Then:
#
# Give an example of warm start. Specifically, in scenario 1:
# train the network for $k$ epochs (max_iter=k), and then without using warm start
# continue the training for another $k$ epochs; in scenario 2: train the network for $k$ epochs, and then using warm start
# continue the training for another $k$ epochs. Check the outputs from training, you will find the different between two scenarios.
# Here $k$ is a parameter of your choice, you can set $k=5$. [10 points]

# %%
### Your code here. Also give some comments about your findings
from sklearn.metrics import accuracy_score
k=5
mlp_mnist = MLPClassifier(verbose = True, hidden_layer_sizes=(50,), batch_size = 5, \
                          max_iter=k, solver='sgd', activation='logistic',\
                          learning_rate = 'constant', learning_rate_init = 0.001, random_state=1,warm_start=True)
mlp_mnist.fit(X_train,y_train)
y_predictions = mlp_mnist.predict(X_test)
acc_pre_warmstart = accuracy_score(y_test, y_predictions)
print(acc_pre_warmstart)
mlp_mnist.set_params(warm_start=False)
mlp_mnist.fit(X_train,y_train)
y_predictions = mlp_mnist.predict(X_test)
acc_post_no_warmstart = accuracy_score(y_test, y_predictions)
print(acc_post_no_warmstart)
# Out:
# Iteration 1, loss = 0.57329662
# Iteration 2, loss = 0.28629488
# Iteration 3, loss = 0.23811091
# Iteration 4, loss = 0.20762641
# Iteration 5, loss = 0.18553770
# Iteration 6, loss = 0.16929318
# Iteration 7, loss = 0.15646485
# Iteration 8, loss = 0.14587802
# Iteration 9, loss = 0.13694593
# Iteration 10, loss = 0.12970190
# Iteration 11, loss = 0.12320933
# Iteration 12, loss = 0.11772963
# Iteration 13, loss = 0.11267477
# Iteration 14, loss = 0.10835127
# Iteration 15, loss = 0.10453760
# Iteration 16, loss = 0.10073217
# Iteration 17, loss = 0.09726995
# Iteration 18, loss = 0.09425700
# Iteration 19, loss = 0.09151431
# Iteration 20, loss = 0.08889736
# Iteration 21, loss = 0.08643857
# Iteration 22, loss = 0.08418907
# Iteration 23, loss = 0.08249839
# Iteration 24, loss = 0.08000014
# Iteration 25, loss = 0.07834150
# Iteration 26, loss = 0.07665299
# Iteration 27, loss = 0.07502774
# Iteration 28, loss = 0.07348437
# Iteration 29, loss = 0.07206173
# Iteration 30, loss = 0.07059095
# Iteration 31, loss = 0.06904452
# Iteration 32, loss = 0.06804828
# Iteration 33, loss = 0.06670843
# Iteration 34, loss = 0.06531548
# Iteration 35, loss = 0.06463879
# Iteration 36, loss = 0.06318098
# Iteration 37, loss = 0.06233041
# Iteration 38, loss = 0.06147756
# Iteration 39, loss = 0.06044707
# Iteration 40, loss = 0.05937900
# Iteration 41, loss = 0.05860980
# Iteration 42, loss = 0.05802491
# Iteration 43, loss = 0.05700755
# Iteration 44, loss = 0.05620678
# Iteration 45, loss = 0.05553365
# Iteration 46, loss = 0.05483653
# Iteration 47, loss = 0.05419409
# Iteration 48, loss = 0.05357554
# Iteration 49, loss = 0.05269414
# Iteration 50, loss = 0.05199743
# 0.9685
# /home/rafrod513/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 0.57329662
# Iteration 2, loss = 0.28629488
# Iteration 3, loss = 0.23811091
# Iteration 4, loss = 0.20762641
# Iteration 5, loss = 0.18553770
# Iteration 6, loss = 0.16929318
# Iteration 7, loss = 0.15646485
# Iteration 8, loss = 0.14587802
# Iteration 9, loss = 0.13694593
# Iteration 10, loss = 0.12970190
# Iteration 11, loss = 0.12320933
# Iteration 12, loss = 0.11772963
# Iteration 13, loss = 0.11267477
# Iteration 14, loss = 0.10835127
# Iteration 15, loss = 0.10453760
# Iteration 16, loss = 0.10073217
# Iteration 17, loss = 0.09726995
# Iteration 18, loss = 0.09425700
# Iteration 19, loss = 0.09151431
# Iteration 20, loss = 0.08889736
# Iteration 21, loss = 0.08643857
# Iteration 22, loss = 0.08418907
# Iteration 23, loss = 0.08249839
# Iteration 24, loss = 0.08000014
# Iteration 25, loss = 0.07834150
# Iteration 26, loss = 0.07665299
# Iteration 27, loss = 0.07502774
# Iteration 28, loss = 0.07348437
# Iteration 29, loss = 0.07206173
# Iteration 30, loss = 0.07059095
# Iteration 31, loss = 0.06904452
# Iteration 32, loss = 0.06804828
# Iteration 33, loss = 0.06670843
# Iteration 34, loss = 0.06531548
# Iteration 35, loss = 0.06463879
# Iteration 36, loss = 0.06318098
# Iteration 37, loss = 0.06233041
# Iteration 38, loss = 0.06147756
# Iteration 39, loss = 0.06044707
# Iteration 40, loss = 0.05937900
# Iteration 41, loss = 0.05860980
# Iteration 42, loss = 0.05802491
# Iteration 43, loss = 0.05700755
# Iteration 44, loss = 0.05620678
# Iteration 45, loss = 0.05553365
# Iteration 46, loss = 0.05483653
# Iteration 47, loss = 0.05419409
# Iteration 48, loss = 0.05357554
# Iteration 49, loss = 0.05269414
# Iteration 50, loss = 0.05199743
# 0.9685
# /home/rafrod513/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
mlp_mnist = MLPClassifier(verbose = True, hidden_layer_sizes=(50,), batch_size = 5, \
                          max_iter=k, solver='sgd', activation='logistic',\
                          learning_rate = 'constant', learning_rate_init = 0.001, random_state=1,warm_start=True)
mlp_mnist.fit(X_train,y_train)
y_predictions = mlp_mnist.predict(X_test)
acc_pre_warmstart = accuracy_score(y_test, y_predictions)
print(acc_pre_warmstart)
mlp_mnist.fit(X_train,y_train)
y_predictions = mlp_mnist.predict(X_test)
acc_post_warmstart = accuracy_score(y_test, y_predictions)
print(acc_post_warmstart)
# Out:
# Iteration 1, loss = 0.57329662
# Iteration 2, loss = 0.28629488
# Iteration 3, loss = 0.23811091
# Iteration 4, loss = 0.20762641
# Iteration 5, loss = 0.18553770
# Iteration 6, loss = 0.16929318
# Iteration 7, loss = 0.15646485
# Iteration 8, loss = 0.14587802
# Iteration 9, loss = 0.13694593
# Iteration 10, loss = 0.12970190
# Iteration 11, loss = 0.12320933
# Iteration 12, loss = 0.11772963
# Iteration 13, loss = 0.11267477
# Iteration 14, loss = 0.10835127
# Iteration 15, loss = 0.10453760
# Iteration 16, loss = 0.10073217
# Iteration 17, loss = 0.09726995
# Iteration 18, loss = 0.09425700
# Iteration 19, loss = 0.09151431
# Iteration 20, loss = 0.08889736
# Iteration 21, loss = 0.08643857
# Iteration 22, loss = 0.08418907
# Iteration 23, loss = 0.08249839
# Iteration 24, loss = 0.08000014
# Iteration 25, loss = 0.07834150
# Iteration 26, loss = 0.07665299
# Iteration 27, loss = 0.07502774
# Iteration 28, loss = 0.07348437
# Iteration 29, loss = 0.07206173
# Iteration 30, loss = 0.07059095
# Iteration 31, loss = 0.06904452
# Iteration 32, loss = 0.06804828
# Iteration 33, loss = 0.06670843
# Iteration 34, loss = 0.06531548
# Iteration 35, loss = 0.06463879
# Iteration 36, loss = 0.06318098
# Iteration 37, loss = 0.06233041
# Iteration 38, loss = 0.06147756
# Iteration 39, loss = 0.06044707
# Iteration 40, loss = 0.05937900
# Iteration 41, loss = 0.05860980
# Iteration 42, loss = 0.05802491
# Iteration 43, loss = 0.05700755
# Iteration 44, loss = 0.05620678
# Iteration 45, loss = 0.05553365
# Iteration 46, loss = 0.05483653
# Iteration 47, loss = 0.05419409
# Iteration 48, loss = 0.05357554
# Iteration 49, loss = 0.05269414
# Iteration 50, loss = 0.05199743
# 0.9685
# /home/rafrod513/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 0.05129788
# Iteration 2, loss = 0.05072636
# Iteration 3, loss = 0.05043541
# Iteration 4, loss = 0.04979898
# Iteration 5, loss = 0.04923291
# Iteration 6, loss = 0.04867154
# Iteration 7, loss = 0.04826586
# Iteration 8, loss = 0.04741866
# Iteration 9, loss = 0.04733553
# Iteration 10, loss = 0.04681812
# Iteration 11, loss = 0.04614600
# Iteration 12, loss = 0.04579316
# Iteration 13, loss = 0.04554663
# Iteration 14, loss = 0.04503739
# Iteration 15, loss = 0.04476104
# Iteration 16, loss = 0.04432113
# Iteration 17, loss = 0.04387203
# Iteration 18, loss = 0.04343532
# Iteration 19, loss = 0.04329371
# Iteration 20, loss = 0.04281461
# Iteration 21, loss = 0.04249219
# Iteration 22, loss = 0.04238826
# Iteration 23, loss = 0.04191199
# Iteration 24, loss = 0.04140828
# Iteration 25, loss = 0.04132779
# Iteration 26, loss = 0.04100384
# Iteration 27, loss = 0.04078583
# Iteration 28, loss = 0.04036876
# Iteration 29, loss = 0.04025865
# Iteration 30, loss = 0.03988273
# Iteration 31, loss = 0.03986334
# Iteration 32, loss = 0.03934384
# Iteration 33, loss = 0.03915909
# Iteration 34, loss = 0.03881880
# Iteration 35, loss = 0.03877583
# Iteration 36, loss = 0.03851792
# Iteration 37, loss = 0.03827568
# Iteration 38, loss = 0.03829990
# Iteration 39, loss = 0.03783471
# Iteration 40, loss = 0.03755168
# Iteration 41, loss = 0.03768050
# Iteration 42, loss = 0.03728530
# Iteration 43, loss = 0.03725238
# Iteration 44, loss = 0.03686553
# Iteration 45, loss = 0.03674364
# Iteration 46, loss = 0.03679601
# Iteration 47, loss = 0.03645913
# Iteration 48, loss = 0.03629535
# Iteration 49, loss = 0.03607850
# Iteration 50, loss = 0.03606873
# 0.9693
# /home/rafrod513/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# The training set usally remains the same after a warm start. Here, we will use a very similar bit not identical dataset after the warm start:
# <br>
# <br>
# **Q1-1**. Randomly divide the MNIST dataset into three part: train1 (50000), train2(10000), test (10000). Make sure that all number classes are presented in both train1, and train2. Hints: use train_test_split(). [10 points]

# %%
### Your code here. Also give some comments about your findings
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
y = y.astype(int)
X = ((X / 255.) - .5) * 2
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=50000, stratify=y, random_state=42)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_test, y_test, train_size=10000, test_size=10000, stratify=y_test, random_state=42)
print("Train1 shape:", X_train.shape, y_train.shape)
print("Train2 shape:", X_train2.shape, y_train2.shape)
print("Test shape:", X_test2.shape, y_test2.shape)
# Out:
# /home/rafrod513/anaconda3/lib/python3.11/site-packages/sklearn/datasets/_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# Train1 shape: (50000, 784) (50000,)
# Train2 shape: (10000, 784) (10000,)
# Test shape: (10000, 784) (10000,)

# %% [markdown]
# **Q1-2**. Use warm start and train your model using the train1 dataset for $2k$ epochs. Then, using warm start, continute the training with train2 dataset for another $2k$ epochs. [10 points]
# <br>
# <br>
# Here $k$ is the same parameter you used above. Notice that each point
# is considered $2k$ times in this training, exactly as in part 0.
# <br>
# <br>
# In effect this process of training tries spend more time learning half of the training set, and then moves to the second part of the training set to spend equal time.

# %%
### Your code here. Also give some comments about your findings
mlp_mnist = MLPClassifier(verbose = True, hidden_layer_sizes=(50,), batch_size = 5, \
                          max_iter=2*k, solver='sgd', activation='logistic',\
                          learning_rate = 'constant', learning_rate_init = 0.001, random_state=1,warm_start=True)
mlp_mnist.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 0.84597052
# Iteration 2, loss = 0.37422200
# Iteration 3, loss = 0.30949003
# Iteration 4, loss = 0.27597400
# Iteration 5, loss = 0.25237148
# Iteration 6, loss = 0.23373194
# Iteration 7, loss = 0.21865330
# Iteration 8, loss = 0.20590202
# Iteration 9, loss = 0.19454532
# Iteration 10, loss = 0.18453721
# Iteration 11, loss = 0.17666133
# Iteration 12, loss = 0.16823244
# Iteration 13, loss = 0.16125237
# Iteration 14, loss = 0.15474165
# Iteration 15, loss = 0.14969776
# Iteration 16, loss = 0.14403381
# Iteration 17, loss = 0.13912742
# Iteration 18, loss = 0.13502062
# Iteration 19, loss = 0.13086168
# Iteration 20, loss = 0.12673554
# Iteration 21, loss = 0.12341348
# Iteration 22, loss = 0.12025922
# Iteration 23, loss = 0.11705455
# Iteration 24, loss = 0.11391850
# Iteration 25, loss = 0.11121995
# Iteration 26, loss = 0.10846648
# Iteration 27, loss = 0.10605672
# Iteration 28, loss = 0.10372269
# Iteration 29, loss = 0.10164264
# Iteration 30, loss = 0.09948917
# Iteration 31, loss = 0.09739431
# Iteration 32, loss = 0.09537364
# Iteration 33, loss = 0.09322579
# Iteration 34, loss = 0.09171549
# Iteration 35, loss = 0.09003092
# Iteration 36, loss = 0.08829926
# Iteration 37, loss = 0.08685988
# Iteration 38, loss = 0.08520203
# Iteration 39, loss = 0.08381168
# Iteration 40, loss = 0.08241300
# Iteration 41, loss = 0.08086828
# Iteration 42, loss = 0.07971713
# Iteration 43, loss = 0.07853804
# Iteration 44, loss = 0.07714854
# Iteration 45, loss = 0.07594898
# Iteration 46, loss = 0.07480741
# Iteration 47, loss = 0.07372771
# Iteration 48, loss = 0.07259761
# Iteration 49, loss = 0.07139943
# Iteration 50, loss = 0.07026382
# /home/rafrod513/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(activation='logistic', batch_size=10, hidden_layer_sizes=(50,),
#               max_iter=50, random_state=1, solver='sgd', verbose=True,
#               warm_start=True)

# %%
y_predictions = mlp_mnist.predict(X_test2)
acc = accuracy_score(y_test2, y_predictions)
print(acc)
# Out:
# 0.9648

# %%
mlp_mnist.fit(X_train2,y_train2)
y_predictions = mlp_mnist.predict(X_test2)
acc = accuracy_score(y_test2, y_predictions)
print(acc)
# Out:
# Iteration 1, loss = 0.12107360
# Iteration 2, loss = 0.11327622
# Iteration 3, loss = 0.10856398
# Iteration 4, loss = 0.10459783
# Iteration 5, loss = 0.10066438
# Iteration 6, loss = 0.09624246
# Iteration 7, loss = 0.09449466
# Iteration 8, loss = 0.09082243
# Iteration 9, loss = 0.08833404
# Iteration 10, loss = 0.08619235
# Iteration 11, loss = 0.08368877
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 0.9653

# %% [markdown]
# **Q1-3**. Which of the two above strategies
# works better? (Q1-0 or Q1-2). Feel free to experiment and report your findings. [10 pts]

# %% [markdown]
# # Report of findings
# ## Looking at the both Q1-0 and Q1-2 qhile Q1-0 was slightly more accurate it did not prove to be as fast as Q1-2 so I would much rather go for Q1-2 in future iterations

# %%
# For grader use only

maxScore = maxScore + 40

# %% [markdown]
# --------------------------
# --------------------------
# --------------------------

# %% [markdown]
# ##  <font color='blue'> Q2. How Powerful are Neural Networks? [20 pts]
#
# There is a lot of hype around Neural Networks, and their ability to solver problems. This is of course justified, but we should always be aware of their limitations.

# %% [markdown]
# Recall that every row in the matrix $X$  above comes from an image. Every entry of a row corresponds to a (grayscale) pixel. In particular, the first colum of $X$ contains the grayscale values of the first pixels of the images in the data set.
# <br>
# <br>
# We will now 'hide' the label of the image, inside the image itself.
# Here is one way to do that: Replace the top-left pixel of the image (which is a value from 0 to 255) with the label for that image. For example, if the image
# contains number 3, then the first pixel of the image will now be set to 3. (In fact, let's set this to 3/255 because we already divided all pixel values by 255).

# %% [markdown]
# **Q2-0.** Create a new dataset $X1$, where each row is the same as the corresponding row of $X$, except in the first column, which contains the label of the corresponding image, divided by 255. Then split
# the set $X1$ into a training set and a test set, as we did with $X$. [10 pts]
#
# Hints: make a copy of X and work on the copy data: X1 = X.copy()

# %%
# your code here
#
#
#
#

# %% [markdown]
# **Q2-1.** With the label of the image 'planted' in the image itself, a Neural Network can achieve accuracy 100%. This is because all the weights connecting to pixels $2...28^2$ can be set to 0, and so effectively the only feature that will be taken into account is the first pixel. The question is whether an MLP can indeed 'discover' this weighting via training. [10 pts]
# <br>
# <br>
# Use an MLP classifier  with one hidden layer of any size you want. Train it on $X1$ and report the accuracy. Does it reach 100\%? Is the accuracy better relative to training with the original input $X$?

# %%
# for grader use

# Total Grade Calculation

maxScore = maxScore + 20
score = actualScore*100/maxScore
